# %%
#load the fnirs data

import numpy as np
import pandas as pd
import scipy.io as sio

def load_data(data_path):
    data = sio.loadmat(data_path)
    print(data['Data_fNIRS'])
    return data


data_path ="fNIRS_HCP_SubjSpecific.mat"

data = load_data(data_path)
# Out:
# [[array([[array([[-6.06126970e-07, -1.05524789e-07, -1.19202505e-07, ...,
#                    3.01904254e-06, -1.65124420e-06, -8.57621748e-08],
#                  [-9.11788180e-07, -2.08170084e-07, -2.19231254e-07, ...,
#                    6.71842828e-06, -2.76607825e-06, -1.48980634e-07],
#                  [-5.77859446e-07, -1.86429803e-07, -9.55050416e-08, ...,
#                    5.39870836e-06,  2.68429878e-06, -1.27618747e-07],
#                  ...,
#                  [ 2.04683474e-07,  3.02578308e-07, -2.88341993e-07, ...,
#                   -6.37352791e-06,  7.16243451e-07,  3.78874147e-07],
#                  [ 2.13633166e-07,  2.50814631e-07, -2.83600930e-07, ...,
#                   -1.12906542e-05,  1.44742067e-06,  2.76170438e-07],
#                  [ 1.70413760e-07,  1.25296407e-07, -3.61534805e-07, ...,
#                   -5.91748337e-06,  1.26755499e-06,  1.99892887e-07]])   ,
#           array([[-6.06126970e-07, -1.05524789e-07, -1.19202505e-07, ...,
# ...

# %%
print(data['Data_fNIRS'][0].shape)
# Out:
# (2,)
