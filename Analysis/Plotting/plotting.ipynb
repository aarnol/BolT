# %%
import os
import numpy as np
import matplotlib.pyplot as plt 
os.getcwd()
# Out:
# 'c:\\Users\\Alex\\Documents\\BolT\\Analysis\\Plotting'

# %%
# Define the paths to save the metrics and results
import os
name = "hcpWM_fNIRS_HbC_hcpWM_newMNI_HBC"
step_metrics_path = os.path.join("..", "Logs", name, "step_metrics.pkl")
epoch_metrics_path = os.path.join("..", "Logs", name, "epoch_metrics.pkl")
test_metrics_path = os.path.join("..", "Logs", name, "test_metrics.pkl")
train_metrics_path = os.path.join("..", "Logs", name, "train_metrics.pkl")

# %%
import pickle

# Define the path to the pickle file
pickle_path = step_metrics_path

# Load the pickle file
with open(pickle_path, 'rb') as f:
    epoch_metrics = pickle.load(f)
epoch_metrics
# Out:
# [{'accuracy': 0.6875,
#   'precision': np.float64(0.6363636363636364),
#   'recall': np.float64(0.875),
#   'roc': np.float64(0.8125),
#   'loss': 0.7078820466995239},
#  {'accuracy': 0.3125,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.23076923076923078),
#   'roc': np.float64(0.23076923076923078),
#   'loss': 0.8916335701942444},
#  {'accuracy': 0.375,
#   'precision': np.float64(0.38461538461538464),
#   'recall': np.float64(0.7142857142857143),
#   'roc': np.float64(0.36507936507936506),
#   'loss': 0.8355846405029297},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.6875),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.309090909090909),
#   'loss': 0.7239049673080444},
#  {'accuracy': 0.375,
#   'precision': np.float64(0.4),
#   'recall': np.float64(0.8571428571428571),
#   'roc': np.float64(0.5555555555555556),
#   'loss': 0.9251832962036133},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.4666666666666667),
#   'recall': np.float64(0.875),
#   'roc': np.float64(0.328125),
#   'loss': 0.8744794130325317},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.4375),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.47619047619047616),
#   'loss': 0.7956942915916443},
#  {'accuracy': 0.8125,
#   'precision': np.float64(0.7777777777777778),
#   'recall': np.float64(0.875),
#   'roc': np.float64(0.8125),
#   'loss': 0.6552095413208008},
#  {'accuracy': 0.375,
#   'precision': np.float64(0.42857142857142855),
#   'recall': np.float64(0.3333333333333333),
#   'roc': np.float64(0.46031746031746035),
#   'loss': 0.782426655292511},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.4),
#   'recall': np.float64(0.25),
#   'roc': np.float64(0.453125),
#   'loss': 0.7613809108734131},
#  {'accuracy': 0.4375,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.1),
#   'roc': np.float64(0.75),
#   'loss': 0.7568040490150452},
#  {'accuracy': 0.375,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.09090909090909091),
#   'roc': np.float64(0.7636363636363637),
#   'loss': 0.7719492316246033},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.2698412698412698),
#   'loss': 0.778496503829956},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.4),
#   'recall': np.float64(0.3333333333333333),
#   'roc': np.float64(0.5833333333333334),
#   'loss': 0.6915318369865417},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.375),
#   'roc': np.float64(0.578125),
#   'loss': 0.7177161574363708},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.4444444444444444),
#   'recall': np.float64(0.5714285714285714),
#   'roc': np.float64(0.4603174603174603),
#   'loss': 0.7226437926292419},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.6),
#   'recall': np.float64(0.375),
#   'roc': np.float64(0.765625),
#   'loss': 0.6708918809890747},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.2857142857142857),
#   'recall': np.float64(0.3333333333333333),
#   'roc': np.float64(0.3833333333333333),
#   'loss': 0.7601509094238281},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.5714285714285714),
#   'recall': np.float64(0.5714285714285714),
#   'roc': np.float64(0.5396825396825397),
#   'loss': 0.6969308257102966},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.4),
#   'recall': np.float64(0.25),
#   'roc': np.float64(0.265625),
#   'loss': 0.7849937677383423},
#  {'accuracy': 0.375,
#   'precision': np.float64(0.2),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.4375),
#   'loss': 0.7434693574905396},
#  {'accuracy': 0.5714285714285714,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.5833333333333334),
#   'loss': 0.6741259694099426},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.375),
#   'roc': np.float64(0.75),
#   'loss': 0.6690588593482971},
#  {'accuracy': 0.3125,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.15384615384615385),
#   'roc': np.float64(0.5384615384615385),
#   'loss': 0.7851687669754028},
#  {'accuracy': 0.6875,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.2857142857142857),
#   'roc': np.float64(0.8253968253968255),
#   'loss': 0.6418814063072205},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.8333333333333334),
#   'recall': np.float64(0.45454545454545453),
#   'roc': np.float64(0.6727272727272727),
#   'loss': 0.748951256275177},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.6),
#   'recall': np.float64(0.42857142857142855),
#   'roc': np.float64(0.6825396825396826),
#   'loss': 0.6862092018127441},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.34375),
#   'loss': 0.7720531225204468},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.7142857142857143),
#   'roc': np.float64(0.6190476190476191),
#   'loss': 0.7021206617355347},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5555555555555556),
#   'recall': np.float64(0.625),
#   'roc': np.float64(0.59375),
#   'loss': 0.693073570728302},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5833333333333334),
#   'recall': np.float64(0.7777777777777778),
#   'roc': np.float64(0.41269841269841273),
#   'loss': 0.7558245062828064},
#  {'accuracy': 0.375,
#   'precision': np.float64(0.4),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.34375),
#   'loss': 0.7481628656387329},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.7142857142857143),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.8166666666666667),
#   'loss': 0.6115819811820984},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.7333333333333333),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.5272727272727272),
#   'loss': 0.6353515982627869},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.46153846153846156),
#   'recall': np.float64(0.8571428571428571),
#   'roc': np.float64(0.5714285714285714),
#   'loss': 0.715043306350708},
#  {'accuracy': 0.375,
#   'precision': np.float64(0.35714285714285715),
#   'recall': np.float64(0.8333333333333334),
#   'roc': np.float64(0.6),
#   'loss': 0.7674335241317749},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.6),
#   'recall': np.float64(0.75),
#   'roc': np.float64(0.625),
#   'loss': 0.6773198843002319},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.4166666666666667),
#   'recall': np.float64(0.7142857142857143),
#   'roc': np.float64(0.5079365079365079),
#   'loss': 0.7261060476303101},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.7),
#   'recall': np.float64(0.875),
#   'roc': np.float64(0.71875),
#   'loss': 0.6672053337097168},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.3333333333333333),
#   'recall': np.float64(0.3333333333333333),
#   'roc': np.float64(0.4833333333333334),
#   'loss': 0.7063819766044617},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.42857142857142855),
#   'roc': np.float64(0.5396825396825397),
#   'loss': 0.723538875579834},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.75),
#   'loss': 0.7192474007606506},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.14583333333333334),
#   'loss': 0.7015693783760071},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.7708333333333333),
#   'loss': 0.6648667454719543},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.84375),
#   'loss': 0.7126107811927795},
#  {'accuracy': 0.1875,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.43589743589743596),
#   'loss': 0.9679430723190308},
#  {'accuracy': 0.6875,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.2857142857142857),
#   'roc': np.float64(0.5396825396825397),
#   'loss': 0.6918495297431946},
#  {'accuracy': 0.375,
#   'precision': np.float64(0.5714285714285714),
#   'recall': np.float64(0.36363636363636365),
#   'roc': np.float64(0.38181818181818183),
#   'loss': 0.7513978481292725},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.5714285714285714),
#   'roc': np.float64(0.5714285714285714),
#   'loss': 0.6918619871139526},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.5),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.21875),
#   'loss': 0.7724181413650513},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.4375),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.17460317460317462),
#   'loss': 0.8490641713142395},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.5),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.546875),
#   'loss': 0.7373919486999512},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5625),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.3015873015873016),
#   'loss': 0.7236005067825317},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.5),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.65625),
#   'loss': 0.7054685354232788},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.625),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.5166666666666666),
#   'loss': 0.6829434037208557},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.7142857142857143),
#   'recall': np.float64(0.9090909090909091),
#   'roc': np.float64(0.6545454545454545),
#   'loss': 0.6616069674491882},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.5384615384615384),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.6984126984126984),
#   'loss': 0.6925817728042603},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.375),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.5333333333333333),
#   'loss': 0.7219184041023254},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.75),
#   'roc': np.float64(0.6875),
#   'loss': 0.6959174871444702},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.6),
#   'recall': np.float64(0.42857142857142855),
#   'roc': np.float64(0.5873015873015873),
#   'loss': 0.6976807713508606},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.640625),
#   'loss': 0.6970052719116211},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.5),
#   'loss': 0.6826573014259338},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.6507936507936509),
#   'loss': 0.6844786405563354},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.578125),
#   'loss': 0.7094683647155762},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.8541666666666666),
#   'loss': 0.574974536895752},
#  {'accuracy': 0.5714285714285714,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.7708333333333333),
#   'loss': 0.6790127158164978},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.71875),
#   'loss': 0.7041244506835938},
#  {'accuracy': 0.1875,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.38461538461538464),
#   'loss': 0.868316113948822},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.42857142857142855),
#   'roc': np.float64(0.6507936507936508),
#   'loss': 0.6734551787376404},
#  {'accuracy': 0.5625,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.36363636363636365),
#   'roc': np.float64(0.7636363636363637),
#   'loss': 0.6854623556137085},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.4666666666666667),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.6666666666666667),
#   'loss': 0.6996542811393738},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.5),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.609375),
#   'loss': 0.7142587900161743},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.4375),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.6507936507936508),
#   'loss': 0.752291738986969},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.5),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.640625),
#   'loss': 0.707362711429596},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5625),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.746031746031746),
#   'loss': 0.6615259051322937},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.4666666666666667),
#   'recall': np.float64(0.875),
#   'roc': np.float64(0.65625),
#   'loss': 0.7235828638076782},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.625),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.6833333333333333),
#   'loss': 0.6583932042121887},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.8181818181818182),
#   'roc': np.float64(0.6181818181818182),
#   'loss': 0.6762765049934387},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.5384615384615384),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.746031746031746),
#   'loss': 0.6900777220726013},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.5555555555555556),
#   'recall': np.float64(0.8333333333333334),
#   'roc': np.float64(0.8),
#   'loss': 0.6497383713722229},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.8),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.828125),
#   'loss': 0.6624433398246765},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.2857142857142857),
#   'roc': np.float64(0.46031746031746035),
#   'loss': 0.7281062006950378},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.4),
#   'recall': np.float64(0.25),
#   'roc': np.float64(0.546875),
#   'loss': 0.6998175978660583},
#  {'accuracy': 0.6875,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.16666666666666666),
#   'roc': np.float64(0.43333333333333335),
#   'loss': 0.6680023670196533},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.47619047619047616),
#   'loss': 0.7187138795852661},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.5625),
#   'loss': 0.7117341160774231},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.45833333333333337),
#   'loss': 0.6394047141075134},
#  {'accuracy': 0.5714285714285714,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.4583333333333333),
#   'loss': 0.7106003165245056},
#  {'accuracy': 0.5625,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.125),
#   'roc': np.float64(0.5),
#   'loss': 0.7407047748565674},
#  {'accuracy': 0.25,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.07692307692307693),
#   'roc': np.float64(0.5641025641025641),
#   'loss': 0.8299328088760376},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.25),
#   'recall': np.float64(0.14285714285714285),
#   'roc': np.float64(0.4444444444444444),
#   'loss': 0.7218359112739563},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.5454545454545454),
#   'roc': np.float64(0.6909090909090909),
#   'loss': 0.680252730846405},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.5873015873015873),
#   'loss': 0.7127934098243713},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.5),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.4375),
#   'loss': 0.7231460213661194},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.4375),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.7301587301587301),
#   'loss': 0.7384322881698608},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.5),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.921875),
#   'loss': 0.6542527079582214},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5625),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.6190476190476191),
#   'loss': 0.6865494251251221},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.5),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.625),
#   'loss': 0.7069329023361206},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.6923076923076923),
#   'recall': np.float64(0.9),
#   'roc': np.float64(0.7833333333333334),
#   'loss': 0.6455548405647278},
#  {'accuracy': 0.8125,
#   'precision': np.float64(0.7857142857142857),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.8181818181818182),
#   'loss': 0.633407711982727},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.4666666666666667),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.873015873015873),
#   'loss': 0.6777894496917725},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.45454545454545453),
#   'recall': np.float64(0.8333333333333334),
#   'roc': np.float64(0.7999999999999999),
#   'loss': 0.6810169816017151},
#  {'accuracy': 0.25,
#   'precision': np.float64(0.3333333333333333),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.328125),
#   'loss': 0.7471935749053955},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.42857142857142855),
#   'roc': np.float64(0.5238095238095238),
#   'loss': 0.6857550740242004},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.375),
#   'roc': np.float64(0.6875),
#   'loss': 0.6782662272453308},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.5333333333333333),
#   'loss': 0.6773865818977356},
#  {'accuracy': 0.6875,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.2857142857142857),
#   'roc': np.float64(0.6190476190476191),
#   'loss': 0.67183917760849},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.84375),
#   'loss': 0.6781683564186096},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.5625),
#   'loss': 0.6058253049850464},
#  {'accuracy': 0.7142857142857143,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.3333333333333333),
#   'roc': np.float64(0.7083333333333334),
#   'loss': 0.6426173448562622},
#  {'accuracy': 0.5625,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.125),
#   'roc': np.float64(0.703125),
#   'loss': 0.6942347288131714},
#  {'accuracy': 0.3125,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.15384615384615385),
#   'roc': np.float64(0.7179487179487181),
#   'loss': 0.7834933400154114},
#  {'accuracy': 0.625,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.14285714285714285),
#   'roc': np.float64(0.5873015873015872),
#   'loss': 0.6685869693756104},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.8571428571428571),
#   'recall': np.float64(0.5454545454545454),
#   'roc': np.float64(0.6181818181818182),
#   'loss': 0.6801202893257141},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.5714285714285714),
#   'roc': np.float64(0.6031746031746033),
#   'loss': 0.7183777689933777},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.625),
#   'roc': np.float64(0.53125),
#   'loss': 0.7001173496246338},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.42857142857142855),
#   'recall': np.float64(0.8571428571428571),
#   'roc': np.float64(0.4603174603174603),
#   'loss': 0.7579256892204285},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.6153846153846154),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.96875),
#   'loss': 0.586026668548584},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.5333333333333333),
#   'recall': np.float64(0.8888888888888888),
#   'roc': np.float64(0.7619047619047619),
#   'loss': 0.651689350605011},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5384615384615384),
#   'recall': np.float64(0.875),
#   'roc': np.float64(0.71875),
#   'loss': 0.6626818180084229},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.6363636363636364),
#   'recall': np.float64(0.7),
#   'roc': np.float64(0.5833333333333334),
#   'loss': 0.6846302151679993},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.7),
#   'recall': np.float64(0.6363636363636364),
#   'roc': np.float64(0.4909090909090909),
#   'loss': 0.6898195743560791},
#  {'accuracy': 0.375,
#   'precision': np.float64(0.4),
#   'recall': np.float64(0.8571428571428571),
#   'roc': np.float64(0.4603174603174603),
#   'loss': 0.7321672439575195},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.46153846153846156),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.7333333333333334),
#   'loss': 0.6688017845153809},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.6363636363636364),
#   'recall': np.float64(0.875),
#   'roc': np.float64(0.75),
#   'loss': 0.6264315247535706},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.5714285714285714),
#   'recall': np.float64(0.5714285714285714),
#   'roc': np.float64(0.6190476190476191),
#   'loss': 0.6871191263198853},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5714285714285714),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.5),
#   'loss': 0.7262569665908813},
#  {'accuracy': 0.6875,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.16666666666666666),
#   'roc': np.float64(0.7666666666666667),
#   'loss': 0.6349552869796753},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.6666666666666666),
#   'recall': np.float64(0.2857142857142857),
#   'roc': np.float64(0.746031746031746),
#   'loss': 0.6473205089569092},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.65625),
#   'loss': 0.7108448147773743},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.0),
#   'recall': np.float64(0.0),
#   'roc': np.float64(0.6666666666666666),
#   'loss': 0.5973901152610779},
#  {'accuracy': 0.6428571428571429,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.16666666666666666),
#   'roc': np.float64(0.9583333333333334),
#   'loss': 0.5805333852767944},
#  {'accuracy': 0.5625,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.125),
#   'roc': np.float64(0.40625),
#   'loss': 0.7418862581253052},
#  {'accuracy': 0.375,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.23076923076923078),
#   'roc': np.float64(0.9487179487179488),
#   'loss': 0.7401065826416016},
#  {'accuracy': 0.625,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.14285714285714285),
#   'roc': np.float64(0.8095238095238095),
#   'loss': 0.6406198740005493},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.8571428571428571),
#   'recall': np.float64(0.5454545454545454),
#   'roc': np.float64(0.7636363636363637),
#   'loss': 0.6787764430046082},
#  {'accuracy': 0.8125,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.5714285714285714),
#   'roc': np.float64(0.8571428571428572),
#   'loss': 0.6014785170555115},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.375),
#   'roc': np.float64(0.65625),
#   'loss': 0.6673657298088074},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.6),
#   'recall': np.float64(0.8571428571428571),
#   'roc': np.float64(0.8412698412698413),
#   'loss': 0.6277725696563721},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.7),
#   'recall': np.float64(0.875),
#   'roc': np.float64(0.796875),
#   'loss': 0.6342586278915405},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.6153846153846154),
#   'recall': np.float64(0.8888888888888888),
#   'roc': np.float64(0.6825396825396826),
#   'loss': 0.6565611362457275},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5333333333333333),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.46875),
#   'loss': 0.7453247308731079},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.6428571428571429),
#   'recall': np.float64(0.9),
#   'roc': np.float64(0.55),
#   'loss': 0.6529993414878845},
#  {'accuracy': 0.875,
#   'precision': np.float64(0.8461538461538461),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.9818181818181819),
#   'loss': 0.5096872448921204},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.5833333333333334),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.8095238095238095),
#   'loss': 0.6368787884712219},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.46153846153846156),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.95),
#   'loss': 0.6083932518959045},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.6666666666666666),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.890625),
#   'loss': 0.5936872363090515},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.6),
#   'recall': np.float64(0.8571428571428571),
#   'roc': np.float64(0.761904761904762),
#   'loss': 0.6373718976974487},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.6666666666666666),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.953125),
#   'loss': 0.5706875920295715},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.6333333333333334),
#   'loss': 0.6690500974655151},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.42857142857142855),
#   'roc': np.float64(0.7301587301587302),
#   'loss': 0.6233064532279968},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.8),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.796875),
#   'loss': 0.5850340723991394},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.25),
#   'roc': np.float64(0.7083333333333333),
#   'loss': 0.543199360370636},
#  {'accuracy': 0.7142857142857143,
#   'precision': np.float64(0.6666666666666666),
#   'recall': np.float64(0.6666666666666666),
#   'roc': np.float64(0.8541666666666666),
#   'loss': 0.5252872705459595},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.375),
#   'roc': np.float64(0.640625),
#   'loss': 0.7189232110977173},
#  {'accuracy': 0.4375,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.3076923076923077),
#   'roc': np.float64(0.46153846153846156),
#   'loss': 0.9596200585365295},
#  {'accuracy': 0.6875,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.2857142857142857),
#   'roc': np.float64(0.761904761904762),
#   'loss': 0.6058095097541809},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.8333333333333334),
#   'recall': np.float64(0.45454545454545453),
#   'roc': np.float64(0.6727272727272727),
#   'loss': 0.7716772556304932},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.2857142857142857),
#   'roc': np.float64(0.7142857142857143),
#   'loss': 0.6427660584449768},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.6),
#   'recall': np.float64(0.375),
#   'roc': np.float64(0.71875),
#   'loss': 0.6634777784347534},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.42857142857142855),
#   'roc': np.float64(0.7936507936507936),
#   'loss': 0.6197855472564697},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.6666666666666666),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.875),
#   'loss': 0.6011937260627747},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.6),
#   'recall': np.float64(0.6666666666666666),
#   'roc': np.float64(0.6031746031746033),
#   'loss': 0.6909040808677673},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.75),
#   'roc': np.float64(0.78125),
#   'loss': 0.6090721487998962},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.6666666666666666),
#   'recall': np.float64(0.8),
#   'roc': np.float64(0.7),
#   'loss': 0.6066621541976929},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.8),
#   'recall': np.float64(0.7272727272727273),
#   'roc': np.float64(0.7818181818181819),
#   'loss': 0.5618201494216919},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.46153846153846156),
#   'recall': np.float64(0.8571428571428571),
#   'roc': np.float64(0.7460317460317459),
#   'loss': 0.6650753021240234},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.4166666666666667),
#   'recall': np.float64(0.8333333333333334),
#   'roc': np.float64(0.7),
#   'loss': 0.7107828259468079},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.6),
#   'recall': np.float64(0.75),
#   'roc': np.float64(0.71875),
#   'loss': 0.6409599184989929},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.7142857142857143),
#   'roc': np.float64(0.7301587301587302),
#   'loss': 0.6506143808364868},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.75),
#   'roc': np.float64(0.640625),
#   'loss': 0.677436113357544},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.625),
#   'recall': np.float64(0.8333333333333334),
#   'roc': np.float64(0.8666666666666667),
#   'loss': 0.6231316328048706},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.4444444444444444),
#   'recall': np.float64(0.5714285714285714),
#   'roc': np.float64(0.5079365079365079),
#   'loss': 0.7187707424163818},
#  {'accuracy': 0.8125,
#   'precision': np.float64(0.8571428571428571),
#   'recall': np.float64(0.75),
#   'roc': np.float64(0.921875),
#   'loss': 0.611189067363739},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.3333333333333333),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.7083333333333333),
#   'loss': 0.6418172717094421},
#  {'accuracy': 0.7142857142857143,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.7708333333333334),
#   'loss': 0.629440188407898},
#  {'accuracy': 0.6875,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.375),
#   'roc': np.float64(0.984375),
#   'loss': 0.6026884317398071},
#  {'accuracy': 0.5625,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.46153846153846156),
#   'roc': np.float64(0.9230769230769231),
#   'loss': 0.695033609867096},
#  {'accuracy': 0.5,
#   'precision': np.float64(0.3333333333333333),
#   'recall': np.float64(0.14285714285714285),
#   'roc': np.float64(0.746031746031746),
#   'loss': 0.6280156970024109},
#  {'accuracy': 0.4375,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.2727272727272727),
#   'roc': np.float64(0.8363636363636364),
#   'loss': 0.7024378180503845},
#  {'accuracy': 0.8125,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.5714285714285714),
#   'roc': np.float64(0.9047619047619047),
#   'loss': 0.5974467992782593},
#  {'accuracy': 0.8125,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.625),
#   'roc': np.float64(1.0),
#   'loss': 0.592177152633667},
#  {'accuracy': 0.75,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.42857142857142855),
#   'roc': np.float64(0.7777777777777779),
#   'loss': 0.6241310834884644},
#  {'accuracy': 0.8125,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.625),
#   'roc': np.float64(0.921875),
#   'loss': 0.5582215785980225},
#  {'accuracy': 0.6875,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.4444444444444444),
#   'roc': np.float64(0.8095238095238095),
#   'loss': 0.654744565486908},
#  {'accuracy': 0.6875,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.375),
#   'roc': np.float64(0.765625),
#   'loss': 0.6465262174606323},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.8571428571428571),
#   'recall': np.float64(0.6),
#   'roc': np.float64(0.8),
#   'loss': 0.6287672519683838},
#  {'accuracy': 0.8125,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.7272727272727273),
#   'roc': np.float64(0.9636363636363636),
#   'loss': 0.5950524210929871},
#  {'accuracy': 0.9375,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.8571428571428571),
#   'roc': np.float64(0.9841269841269841),
#   'loss': 0.5406778454780579},
#  {'accuracy': 0.875,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.6666666666666666),
#   'roc': np.float64(0.8666666666666667),
#   'loss': 0.5900205969810486},
#  {'accuracy': 0.875,
#   'precision': np.float64(0.875),
#   'recall': np.float64(0.875),
#   'roc': np.float64(0.9375),
#   'loss': 0.5525772571563721},
#  {'accuracy': 0.875,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.7142857142857143),
#   'roc': np.float64(0.8253968253968254),
#   'loss': 0.5607211589813232},
#  {'accuracy': 0.8125,
#   'precision': np.float64(0.7777777777777778),
#   'recall': np.float64(0.875),
#   'roc': np.float64(0.9375),
#   'loss': 0.5805218815803528},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.5555555555555556),
#   'recall': np.float64(0.8333333333333334),
#   'roc': np.float64(0.8333333333333333),
#   'loss': 0.6177349090576172},
#  {'accuracy': 0.5625,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.8571428571428571),
#   'roc': np.float64(0.746031746031746),
#   'loss': 0.6612643003463745},
#  {'accuracy': 0.75,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.9375),
#   'loss': 0.6145933866500854},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.375),
#   'recall': np.float64(0.75),
#   'roc': np.float64(0.8541666666666665),
#   'loss': 0.6272509098052979},
#  {'accuracy': 0.7857142857142857,
#   'precision': np.float64(0.7142857142857143),
#   'recall': np.float64(0.8333333333333334),
#   'roc': np.float64(0.9166666666666667),
#   'loss': 0.5352060794830322},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.625),
#   'recall': np.float64(0.625),
#   'roc': np.float64(0.703125),
#   'loss': 0.6443789601325989},
#  {'accuracy': 0.875,
#   'precision': np.float64(0.8666666666666667),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.7179487179487181),
#   'loss': 0.5377442836761475},
#  {'accuracy': 0.8125,
#   'precision': np.float64(0.75),
#   'recall': np.float64(0.8571428571428571),
#   'roc': np.float64(0.8412698412698413),
#   'loss': 0.5897655487060547},
#  {'accuracy': 0.875,
#   'precision': np.float64(0.9090909090909091),
#   'recall': np.float64(0.9090909090909091),
#   'roc': np.float64(0.8909090909090909),
#   'loss': 0.5301951169967651},
#  {'accuracy': 0.9375,
#   'precision': np.float64(0.875),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.9523809523809523),
#   'loss': 0.540274977684021},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.6666666666666666),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.90625),
#   'loss': 0.577794075012207},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.6666666666666666),
#   'recall': np.float64(0.8571428571428571),
#   'roc': np.float64(0.888888888888889),
#   'loss': 0.5850462317466736},
#  {'accuracy': 0.875,
#   'precision': np.float64(0.8),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.953125),
#   'loss': 0.5058847069740295},
#  {'accuracy': 0.875,
#   'precision': np.float64(0.8181818181818182),
#   'recall': np.float64(1.0),
#   'roc': np.float64(1.0),
#   'loss': 0.5259052515029907},
#  {'accuracy': 0.625,
#   'precision': np.float64(0.625),
#   'recall': np.float64(0.625),
#   'roc': np.float64(0.765625),
#   'loss': 0.5996737480163574},
#  {'accuracy': 0.875,
#   'precision': np.float64(0.8333333333333334),
#   'recall': np.float64(1.0),
#   'roc': np.float64(1.0),
#   'loss': 0.4644041359424591},
#  {'accuracy': 0.75,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.6363636363636364),
#   'roc': np.float64(0.9090909090909092),
#   'loss': 0.5760672688484192},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.6666666666666666),
#   'recall': np.float64(0.5714285714285714),
#   'roc': np.float64(0.7619047619047619),
#   'loss': 0.6216078996658325},
#  {'accuracy': 0.9375,
#   'precision': np.float64(0.8571428571428571),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.9500000000000001),
#   'loss': 0.5032890439033508},
#  {'accuracy': 0.8125,
#   'precision': np.float64(0.8571428571428571),
#   'recall': np.float64(0.75),
#   'roc': np.float64(0.9375),
#   'loss': 0.5098397135734558},
#  {'accuracy': 0.6875,
#   'precision': np.float64(0.625),
#   'recall': np.float64(0.7142857142857143),
#   'roc': np.float64(0.746031746031746),
#   'loss': 0.6227395534515381},
#  {'accuracy': 0.8125,
#   'precision': np.float64(0.7272727272727273),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.96875),
#   'loss': 0.5173294544219971},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.6666666666666666),
#   'recall': np.float64(0.6666666666666666),
#   'roc': np.float64(0.8166666666666667),
#   'loss': 0.5703991055488586},
#  {'accuracy': 0.875,
#   'precision': np.float64(0.7777777777777778),
#   'recall': np.float64(1.0),
#   'roc': np.float64(0.8888888888888888),
#   'loss': 0.5386865139007568},
#  {'accuracy': 0.875,
#   'precision': np.float64(1.0),
#   'recall': np.float64(0.75),
#   'roc': np.float64(0.96875),
#   'loss': 0.5113285183906555},
#  {'accuracy': 0.75,
#   'precision': np.float64(0.5),
#   'recall': np.float64(0.5),
#   'roc': np.float64(0.625),
#   'loss': 0.6371920704841614},
#  {'accuracy': 0.8571428571428571,
#   'precision': np.float64(0.8333333333333334),
#   'recall': np.float64(0.8333333333333334),
#   'roc': np.float64(0.9583333333333334),
#   'loss': 0.48819252848625183}]

# %%
#plots for accuracy, precision, recall, roc, and loss over time
# Extract metrics from 
import matplotlib.pyplot as plt
import numpy as np



accuracy = [metric['accuracy'] for metric in epoch_metrics]
precision = [metric['precision'] for metric in epoch_metrics]
recall = [metric['recall'] for metric in epoch_metrics]
roc = [metric['roc'] for metric in epoch_metrics]
loss = [metric['loss'] for metric in epoch_metrics]


# Plot accuracy over time
plt.figure(figsize=(12, 6))
plt.subplot(2, 3, 1)
plt.plot(accuracy, label='Accuracy')
plt.xlabel('Step')
plt.ylabel('Accuracy')
plt.title('Accuracy over Time')
plt.legend()

# Plot precision over time
plt.subplot(2, 3, 2)
plt.plot(precision, label='Precision')
plt.xlabel('Step')
plt.ylabel('Precision')
plt.title('Precision over Time')
plt.legend()

# Plot recall over time
plt.subplot(2, 3, 3)
plt.plot(recall, label='Recall')
plt.xlabel('Step')
plt.ylabel('Recall')
plt.title('Recall over Time')
plt.legend()

# Plot ROC over time
plt.subplot(2, 3, 4)
plt.plot(roc, label='ROC')
plt.xlabel('Step')
plt.ylabel('ROC')
plt.title('ROC over Time')
plt.legend()

# Plot loss over time
plt.subplot(2, 3, 5)
plt.plot(loss, label='Loss')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Loss over Time')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Trim the arrays to the largest multiple of 50
trimmed_size = (len(accuracy) // 50) * 50

avg_accuracy = np.mean(np.array(accuracy[:trimmed_size]).reshape(-1, 50), axis=1)
avg_precision = np.mean(np.array(precision[:trimmed_size]).reshape(-1, 50), axis=1)
avg_recall = np.mean(np.array(recall[:trimmed_size]).reshape(-1, 50), axis=1)
avg_roc = np.mean(np.array(roc[:trimmed_size]).reshape(-1, 50), axis=1)
avg_loss = np.mean(np.array(loss[:trimmed_size]).reshape(-1, 50), axis=1)

# %%
# Plot averaged metrics over time
# %matplotlib inline
plt.figure(figsize=(12, 6))

# Plot averaged accuracy over time
plt.subplot(2, 3, 1)
plt.plot(avg_accuracy, label='Avg Accuracy')
plt.xlabel('Step')
plt.ylabel('Avg Accuracy')
plt.title('Average Accuracy over Time')
plt.legend()

# Plot averaged precision over time
plt.subplot(2, 3, 2)
plt.plot(avg_precision, label='Avg Precision')
plt.xlabel('Step')
plt.ylabel('Avg Precision')
plt.title('Average Precision over Time')
plt.legend()

# Plot averaged recall over time
plt.subplot(2, 3, 3)
plt.plot(avg_recall, label='Avg Recall')
plt.xlabel('Step')
plt.ylabel('Avg Recall')
plt.title('Average Recall over Time')
plt.legend()

# Plot averaged ROC over time
plt.subplot(2, 3, 4)
plt.plot(avg_roc, label='Avg ROC')
plt.xlabel('Step')
plt.ylabel('Avg ROC')
plt.title('Average ROC over Time')
plt.legend()

# Plot averaged loss over time
plt.subplot(2, 3, 5)
plt.plot(avg_loss, label='Avg Loss')
plt.xlabel('Step')
plt.ylabel('Avg Loss')
plt.title('Average Loss over Time')
plt.legend()
plt.suptitle('Averaged Metrics over Time (10 steps)', fontsize=16)
plt.tight_layout()
plt.show()

# %%
with open(test_metrics_path, 'rb') as f:
    test_results = pickle.load(f)

# Print the contents of the test_results pickle file

# %%
test_metrics = test_results
# Extract metrics from test_metrics
test_accuracy = [metric['accuracy'] for metric in test_metrics]
test_precision = [metric['precision'] for metric in test_metrics]
test_recall = [metric['recall'] for metric in test_metrics]
test_roc = [metric['roc'] for metric in test_metrics]


# Print the metrics
print("Test Accuracy:", test_accuracy)
print("Test Precision:", test_precision)
print("Test Recall:", test_recall)
print("Test ROC:", test_roc)
# Out:
# Test Accuracy: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.4791666666666667, 0.5, 0.4895833333333333, 0.5729166666666666]
# Test Precision: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.3333333333333333), np.float64(0.5), np.float64(0.49382716049382713), np.float64(0.5714285714285714)]
# Test Recall: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.041666666666666664), np.float64(0.10416666666666667), np.float64(0.8333333333333334), np.float64(0.5833333333333334)]
# Test ROC: [np.float64(0.4396701388888889), np.float64(0.4943576388888889), np.float64(0.4796006944444444), np.float64(0.4210069444444444), np.float64(0.4696180555555555), np.float64(0.5303819444444445), np.float64(0.4722222222222222), np.float64(0.5490451388888888), np.float64(0.5529513888888888), np.float64(0.5624999999999999)]

# %%
plt.figure(figsize=(15, 10))

# Plot test accuracy over time
plt.subplot(2, 3, 1)
plt.plot(test_accuracy, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Test Accuracy over Time')
plt.legend()



# Plot test precision over time
plt.subplot(2, 3, 3)
plt.plot(test_precision, label='Test Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.title('Test Precision over Time')
plt.legend()

# Plot test recall over time
plt.subplot(2, 3, 4)
plt.plot(test_recall, label='Test Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.title('Test Recall over Time')
plt.legend()

# Plot test ROC over time
plt.subplot(2, 3, 5)
plt.plot(test_roc, label='Test ROC')
plt.xlabel('Epoch')
plt.ylabel('ROC')
plt.title('Test ROC over Time')
plt.legend()

plt.tight_layout()
plt.show()

# %%
def plot_step_metrics(pickle_path):
    import pickle
    import matplotlib.pyplot as plt
    import numpy as np

    # Load the pickle file
    with open(pickle_path, 'rb') as f:
        epoch_metrics = pickle.load(f)

    accuracy = [metric['accuracy'] for metric in epoch_metrics]
    precision = [metric['precision'] for metric in epoch_metrics]
    recall = [metric['recall'] for metric in epoch_metrics]
    roc = [metric['roc'] for metric in epoch_metrics]
    loss = [metric['loss'] for metric in epoch_metrics]

    # Plot accuracy over time
    plt.figure(figsize=(12, 6))
    plt.subplot(2, 3, 1)
    plt.plot(accuracy, label='Accuracy')
    plt.xlabel('Step')
    plt.ylabel('Accuracy')
    plt.title('Accuracy over Time')
    plt.legend()

    # Plot precision over time
    plt.subplot(2, 3, 2)
    plt.plot(precision, label='Precision')
    plt.xlabel('Step')
    plt.ylabel('Precision')
    plt.title('Precision over Time')
    plt.legend()

    # Plot recall over time
    plt.subplot(2, 3, 3)
    plt.plot(recall, label='Recall')
    plt.xlabel('Step')
    plt.ylabel('Recall')
    plt.title('Recall over Time')
    plt.legend()

    # Plot ROC over time
    plt.subplot(2, 3, 4)
    plt.plot(roc, label='ROC')
    plt.xlabel('Step')
    plt.ylabel('ROC')
    plt.title('ROC over Time')
    plt.legend()

    # Plot loss over time
    plt.subplot(2, 3, 5)
    plt.plot(loss, label='Loss')
    plt.xlabel('Step')
    plt.ylabel('Loss')
    plt.title('Loss over Time')
    plt.legend()

    plt.tight_layout()
    plt.show()


plot_step_metrics(step_metrics_path)

# %%
import pickle
import numpy as np

def plot_test_metrics(test_results_path, test_metrics_path):
    import matplotlib.pyplot as plt

    # Load the test results pickle file
    with open(test_results_path, 'rb') as f:
        test_results = pickle.load(f)

    # Load the test metrics pickle file
    with open(test_metrics_path, 'rb') as f:
        test_metrics = pickle.load(f)

    # Extract metrics from test_results and test_metrics
    test_loss = [result['loss'] for result in test_results]
    test_accuracy = [metric['accuracy'] for metric in test_metrics]
    test_precision = [metric['precision'] for metric in test_metrics]
    test_recall = [metric['recall'] for metric in test_metrics]
    test_roc = [metric['roc'] for metric in test_metrics]

    # Plot test metrics
    plt.figure(figsize=(15, 10))

    # Plot test accuracy over time
    plt.subplot(2, 3, 1)
    plt.plot(test_accuracy, label='Test Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Test Accuracy over Time')
    plt.legend()

    # Plot test loss over time
    plt.subplot(2, 3, 2)
    plt.plot(test_loss, label='Test Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Test Loss over Time')
    plt.legend()

    # Plot test precision over time
    plt.subplot(2, 3, 3)
    plt.plot(test_precision, label='Test Precision')
    plt.xlabel('Epoch')
    plt.ylabel('Precision')
    plt.title('Test Precision over Time')
    plt.legend()

    # Plot test recall over time
    plt.subplot(2, 3, 4)
    plt.plot(test_recall, label='Test Recall')
    plt.xlabel('Epoch')
    plt.ylabel('Recall')
    plt.title('Test Recall over Time')
    plt.legend()

    # Plot test ROC over time
    plt.subplot(2, 3, 5)
    plt.plot(test_roc, label='Test ROC')
    plt.xlabel('Epoch')
    plt.ylabel('ROC')
    plt.title('Test ROC over Time')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example usage

plot_test_metrics(test_results_path, test_metrics_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 70
#      66     plt.show()
#      68 # Example usage
# ---> 70 plot_test_metrics(test_results_path, test_metrics_path)
#
# NameError: name 'test_results_path' is not defined
